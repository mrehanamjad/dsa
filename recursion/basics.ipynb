# %% [markdown]
# # Recursion with parameters
#
# with head (with tail home work)
# ![Recursion with parameters lecture screen short](./asserts/recursion_with_params.png)
#
# backtraking example:
# with tail
# ![Recursion with parameters backtraking tail lecture screen short](./asserts/backtraking-rec.png "Recursion with parameters backtraking Example With Tail")
#
# with head
# ![Recursion with parameters backtraking head lecture screen short](./asserts/backtraking%20head.png "Recursion with parameters backtraking Example With Head")

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Parameterised & Functional Recursion
#
# ### Parameterised V/s Functional Recursion
# - Parameterised: (not return) ![Parameterised Recursion  lecture screen short](./asserts/params-rec.png)
# - Functional Recursion (return): ![ Functional Recursion lecture screen short # 1](./asserts/func-rec1.png)![ Functional Recursion lecture screen short # 2](./asserts/func-rec2.png)
