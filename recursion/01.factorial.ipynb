# %% [markdown]
# n!
#
# - 5! = 5*4*3*2*1
# - 1! = 1
# - 0! = 0
# - 5! = 5 * 4!
# - 4! = 4 * 3!
# - `n! = n * (n-1)!`

# %% [markdown]
# T.C = `O(n)`
# S.P = `O(n) --> Stack Space`

# %%
def factorial(n:int) -> int:
    if n == 0 or n == 1:
        return 1
    return n * factorial(n-1)
print(factorial(5))
# Out:
# 120
